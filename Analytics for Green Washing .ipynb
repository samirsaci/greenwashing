# %%
import pandas as pd
import numpy as np
import ruptures as rpt
import matplotlib.pyplot as plt

# %% [markdown]
# ### Change Point Analysis

# %%
# Create a dataframe
df = pd.read_csv('co2_emissions.csv')

# Display the dataframe
df.set_index('Year', inplace = True)
df.head()
# Out:
#       CO2 Emissions
# Year
# 2010     133.315865
# 2011     127.152790
# 2012     104.545997
# 2013     119.916162
# 2014     126.213360

# %%
# Assuming that the emissions data is in a column named 'CO2 Emissions'
emissions = df['CO2 Emissions'].values

# Detection
algo = rpt.Pelt(model="rbf").fit(emissions)
result = algo.predict(pen=1)

# detection
algo = rpt.Pelt(model="rbf").fit(emissions)
result = algo.predict(pen=1)

# display
rpt.display(emissions, result, figsize=(10, 6))
plt.title('Change Point Detection: Pelt Search Method')
plt.xlabel('Time (Years)')  # Replace with actual time unit in your data
plt.ylabel('CO2 Emissions')  # Replace with actual unit of your emissions data
plt.show()
